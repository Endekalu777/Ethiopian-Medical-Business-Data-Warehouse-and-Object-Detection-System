# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
from scripts.cleaning import *

# %%
# List of file paths to clean
file_paths = [
    '../scrapped_data/@CheMed123_data.csv',
    '../scrapped_data/@DoctorsET_data.csv',
    '../scrapped_data/@EAHCI_data.csv',
    '../scrapped_data/@lobelia4cosmetics_data.csv',
    '../scrapped_data/@yetenaweg_data.csv'
]

# %%
# Clean each dataset and store the paths of cleaned files
cleaned_file_paths = {}
for path in file_paths:
    cleaned_file_paths[path] = clean_dataset(path)

# Display cleaned file paths
for original, cleaned in cleaned_file_paths.items():
    print(f"Cleaned file for {original}: {cleaned}")
# Out:
#                   Missing Values  Percentage
# Channel Title                  0         0.0
# Channel Username               0         0.0
# ID                             0         0.0
# Message                        0         0.0
# Date                           0         0.0
# Media Path                     0         0.0
# views                          0         0.0
# message_link                   0         0.0
#                   Missing Values  Percentage
# Channel Title                  0         0.0
# Channel Username               0         0.0
# ID                             0         0.0
# Message                        0         0.0
# Date                           0         0.0
# Media Path                     0         0.0
# views                          0         0.0
# message_link                   0         0.0
#                   Missing Values  Percentage
# Channel Title                  0         0.0
# Channel Username               0         0.0
# ...
